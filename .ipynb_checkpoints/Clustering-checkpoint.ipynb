# %%
'''
Clustering
-------------
- Unsupervised Learning
- It does not have target value.
- sillihoute score -> accuracy of clustering
    -> how well clusters will be formed?
    ->-1 to 1
    ->less than zero -> Bad Cluster
    ->zero to 0.5 -> average cluster
    ->0.5 to 0.7 -> good cluster
    ->0.7 to 1 or near 1 -> best cluster

Algorithm
-----------
1. K-Means Clustering
2. Agglomerative Clustering
3. Hierachical Clustering

Dimensity Reduction Algorithm
------------------------------
PCA -> Principle Component Analysis
'''
