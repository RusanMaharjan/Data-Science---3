# %%
import pandas as pd

# %%
df = pd.read_csv('hr_cleaned_data.csv')
df.head()
# Out:
#            Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi  Wilson  K  10026          0                0         1
# 1  Ait Sidi  Karthikeyan  10084          1                1         1
# 2      Akinkuolie  Sarah  10196          1                1         0
# 3           Alagbe Trina  10088          1                1         0
# 4        Anderson  Carol  10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert         22          LinkedIn          Exceeds
# 1      Simon Roup          4            Indeed      Fully Meets
# 2  Kissy Sullivan         20          LinkedIn      Fully Meets
# 3    Elijiah Gray         16            Indeed      Fully Meets
# 4  Webster Butler         39     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                 2019-01-17              0        1
# 1                 2016-02-24              0       17
# 2                 2012-05-15              0        3
# 3                 2019-01-03              0       15
# 4                 2016-02-01              0        2
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    object
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    int64
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    object
#  13  State                       582 non-null    object
#  14  Zip                         582 non-null    int64
#  15  DOB                         582 non-null    object
#  16  Gender                      582 non-null    object
#  17  MaritalDesc                 582 non-null    object
#  18  CitizenDesc                 582 non-null    object
#  19  HispanicLatino              582 non-null    object
#  20  RaceDesc                    582 non-null    object
#  21  DateofHire                  582 non-null    object
#  22  DateofTermination           196 non-null    object
#  23  TermReason                  582 non-null    object
#  24  EmploymentStatus            582 non-null    object
#  25  Department                  582 non-null    object
#  26  ManagerName                 582 non-null    object
#  27  ManagerID                   582 non-null    int64
#  28  RecruitmentSource           582 non-null    object
#  29  PerformanceScore            582 non-null    object
#  30  EngagementSurvey            582 non-null    float64
#  31  EmpSatisfaction             582 non-null    int64
#  32  SpecialProjectsCount        582 non-null    int64
#  33  LastPerformanceReview_Date  582 non-null    object
#  34  DaysLateLast30              582 non-null    int64
#  35  Absences                    582 non-null    int64
# dtypes: float64(1), int64(17), object(18)
# memory usage: 163.8+ KB

# %%
def changeDateTime(dataframe, *args):
    for col in args:
        dataframe[col] = pd.to_datetime(dataframe[col], format='mixed')

# %%
changeDateTime(df, 'DateofTermination', 'DOB', 'DateofHire', 'LastPerformanceReview_Date')

# %% [markdown]
# ### Extract Year, Month, Day

# %%
'''
year
month / month_name()
day / day_name()
'''
# dataframe['new_col'] = dataframe[col].dt.year/month/day
# Out:
# '\nyear\nmonth / month_name()\nday / day_name()\n'

# %%
df['HireYear'] = df['DateofHire'].dt.year

# %%
df['HireMonth'] = df['DateofHire'].dt.month
df['HireDay'] = df['DateofHire'].dt.day

# %%
## Extract date name
df['HireMonth_Name'] = df['DateofHire'].dt.month_name()
df['HireDay_Name'] = df['DateofHire'].dt.day_name()

# %% [markdown]
# ### Convert Continuous data to Categorical data

# %%
def convertSalary(salary):
    if salary > 0 and salary <= 70000:
        return 'Low Salary'
    elif salary > 70000 and salary <= 150000:
        return 'Medium Salary'
    else:
        return 'High Salary'

# %%
# apply
df['Salary_Label'] = df['Salary'].apply(convertSalary)

# %% [markdown]
# ### Feature Encoding

# %%
'''
- Manual Encoding
    Dictionary
- Use map() function
    -> dataframe[col_name] = dataframe[col_name].map(dict)
'''
# Out:
# '\n- Manual Encoding\n    Dictionary\n- Use map() function\n    -> dataframe[col_name] = dataframe[col_name].map(dict)\n'

# %%
df['Salary_Label'].unique()
# Out:
# array(['Low Salary', 'Medium Salary', 'High Salary'], dtype=object)

# %%
# Label Encoder
#     High Salary - 0 
#     Low Salary - 1
#     Medium Salary - 2

# %%
salary_dict = {
    'Low Salary': 0,
    'Medium Salary': 1,
    'High Salary': 2
}

# %%
df['salary_label_num'] = df.loc[:,'Salary_Label'].map(salary_dict)

# %%
def manualEncode(dataframe, col_name, *args):
    encode_value = {}
    for idx, val in enumerate(args):
        encode_value[val] = idx

    dataframe[f'{col_name}_id'] = dataframe[col_name].map(encode_value)

# %%
manualEncode(df, 'PerformanceScore', 'Exceeds', 'Fully Meets', 'Needs Improvement', 'PIP')

# %%
manualEncode(df, 'HireDay_Name', 'Tuesday', 'Monday', 'Thursday', 'Wednesday', 'Sunday', 'Friday','Saturday')

# %%
df['ManagerName'].unique()
# Out:
# array(['Michael Albert', 'Simon Roup', 'Kissy Sullivan', 'Elijiah Gray',
#        'Webster Butler', 'Amy Dunn', 'Alex Sweetwater', 'Ketsia Liebig',
#        'Brannon Miller', 'Peter Monroe', 'David Stanley', 'Kelley Spirea',
#        'Brandon R. LeBlanc', 'Janet King', 'John Smith',
#        'Jennifer Zamora', 'Lynn Daneault', 'Eric Dougall',
#        'Debra Houlihan', 'Brian Champaigne', 'Board of Directors'],
#       dtype=object)

# %% [markdown]
# ### Split Columns

# %%
'''
- Use of Split
------------------
- To separate data into multiple columns on the basis of common character.
- df['col_name'].str.split(find, n(no._of_columns)=index, expand=True/False(default))
'''
# Out:
# "\n- Use of Split\n------------------\n- To separate data into multiple columns on the basis of common character.\n- df['col_name'].str.split(find, n(no._of_columns)=index, expand=True/False(default))\n"

# %%
df['Salary_Label'].unique()
# Out:
# array(['Low Salary', 'Medium Salary', 'High Salary'], dtype=object)

# %%
salary_columns = df['Salary_Label'].str.split(' ', n=1, expand=True)
salary_columns.head()
# Out:
#         0       1
# 0     Low  Salary
# 1  Medium  Salary
# 2     Low  Salary
# 3     Low  Salary
# 4     Low  Salary

# %%
hr = pd.read_csv('Dataset/HR_Dataset Refresh.csv')
hr.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
# 3                   1/3/2019              0       15
# 4                   2/1/2016              0        2
#
# [5 rows x 36 columns]

# %%
emp_name = hr['Employee_Name'].str.split(',', n=1, expand=True)
# emp_name.head()

# %%
first_middle = emp_name[1].str.strip().str.split(' ', n=1, expand=True)
# first_middle.head()

# %%
df['E_FirstName'] = first_middle[0]
df['E_MiddleName'] = first_middle[1]
df['E_LastName'] = emp_name[0]

# %%
df
# Out:
#              Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0      Adinolfi  Wilson  K  10026          0                0         1
# 1    Ait Sidi  Karthikeyan  10084          1                1         1
# 2        Akinkuolie  Sarah  10196          1                1         0
# 3             Alagbe Trina  10088          1                1         0
# 4          Anderson  Carol  10069          0                2         0
# ..                     ...    ...        ...              ...       ...
# 577        Anderson  Carol  10069          0                2         0
# 578        Anderson  Linda  10002          0                0         0
# 579        Andreola  Colby  10194          0                0         0
# 580            Athwal  Sam  10062          0                4         1
# 581       Bachiochi  Linda  10114          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0              1       5            4                       0   62506  ...
# 1              5       3            3                       0  104437  ...
# 2              5       5            3                       0   64955  ...
# 3              1       5            3                       0   64991  ...
# 4              5       5            3                       0   50825  ...
# ..           ...     ...          ...                     ...     ...  ...
# 577            5       5            3                       0   50825  ...
# 578            1       5            4                       0   57568  ...
# 579            1       4            3                       0   95660  ...
# 580            1       5            3                       0   59365  ...
# 581            3       5            3                       1   47837  ...
#
#      HireDay  HireMonth_Name HireDay_Name   Salary_Label  salary_label_num  \
# 0          5            July      Tuesday     Low Salary                 0
# 1         30           March       Monday  Medium Salary                 1
# 2          5            July      Tuesday     Low Salary                 0
# 3          7         January       Monday     Low Salary                 0
# 4         11            July       Monday     Low Salary                 0
# ..       ...             ...          ...            ...               ...
# 577       11            July       Monday     Low Salary                 0
# 578        9         January       Monday     Low Salary                 0
# 579       10        November       Monday  Medium Salary                 1
# 580       30       September       Monday     Low Salary                 0
# 581        6            July       Monday     Low Salary                 0
#
#     PerformanceScore_id HireDay_Name_id  E_FirstName E_MiddleName  E_LastName
# 0                     0               0       Wilson            K    Adinolfi
# 1                     1               1  Karthikeyan         None    Ait Sidi
# 2                     1               0        Sarah         None  Akinkuolie
# 3                     1               1        Trina         None      Alagbe
# 4                     1               1        Carol         None    Anderson
# ..                  ...             ...          ...          ...         ...
# 577                   1               1        Carol         None    Anderson
# 578                   0               1        Linda         None    Anderson
# 579                   1               1        Colby         None    Andreola
# 580                   1               1          Sam         None      Athwal
# 581                   1               1        Linda         None   Bachiochi
#
# [582 rows x 48 columns]

# %%
'''
- StandardScaler
- Label Encoder
- One Hot Encoder
- Min Max Scaler
- Robust Scaler
'''
# Out:
# '\n- StandardScaler\n- Label Encoder\n- One Hot Encoder\n- Min Max Scaler\n- Robust Scaler\n'

# %%
import numpy as np
# Michael Albert

# %%
def splitName(name):
    value = name.strip().split() # ['Michael', 'middle', 'Albert']

    if len(value) == 1:
        return pd.Series([value[0], np.nan, np.nan])
    elif len(value) == 2:
        return pd.Series([value[0], np.nan, value[1]])
    else:
        return pd.Series([value[0], value[1], value[2]])

# %%
df[['M_first_name', 'M_middle_name', 'M_last_name']] = df['ManagerName'].apply(splitName)

# %%
df[df['ManagerName'] == 'Brandon R. LeBlanc']
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 45    Boutwell  Bonalyn  10081          1                1         0
# 48           Brown  Mia  10238          1                1         0
# 151     Howard  Estelle  10182          1                1         0
# 179  LaRotonda  William  10038          0                2         1
# 274          Singh  Nan  10039          0                0         0
# 278    Smith  Leigh Ann  10153          1                1         0
# 287      Steans  Tyrone  10147          0                0         1
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 45             1       1            3                       1  106367  ...
# 48             1       1            3                       1   63000  ...
# 151            1       1            3                       0   49920  ...
# 179            1       1            3                       0   64520  ...
# 274            1       1            3                       0   51920  ...
# 278            5       1            3                       1   55000  ...
# 287            1       1            3                       0   63003  ...
#
#       Salary_Label  salary_label_num PerformanceScore_id HireDay_Name_id  \
# 45   Medium Salary                 1                   1               1
# 48      Low Salary                 0                   1               1
# 151     Low Salary                 0                   1               1
# 179     Low Salary                 0                   1               1
# 274     Low Salary                 0                   1               5
# 278     Low Salary                 0                   1               1
# 287     Low Salary                 0                   1               1
#
#      E_FirstName E_MiddleName E_LastName M_first_name M_middle_name  \
# 45       Bonalyn         None   Boutwell      Brandon            R.
# 48           Mia         None      Brown      Brandon            R.
# 151      Estelle         None     Howard      Brandon            R.
# 179      William         None  LaRotonda      Brandon            R.
# 274          Nan         None      Singh      Brandon            R.
# 278        Leigh          Ann      Smith      Brandon            R.
# 287       Tyrone         None     Steans      Brandon            R.
#
#     M_last_name
# 45      LeBlanc
# 48      LeBlanc
# 151     LeBlanc
# 179     LeBlanc
# 274     LeBlanc
# 278     LeBlanc
# 287     LeBlanc
#
# [7 rows x 51 columns]

# %%
df
# Out:
#              Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0      Adinolfi  Wilson  K  10026          0                0         1
# 1    Ait Sidi  Karthikeyan  10084          1                1         1
# 2        Akinkuolie  Sarah  10196          1                1         0
# 3             Alagbe Trina  10088          1                1         0
# 4          Anderson  Carol  10069          0                2         0
# ..                     ...    ...        ...              ...       ...
# 577        Anderson  Carol  10069          0                2         0
# 578        Anderson  Linda  10002          0                0         0
# 579        Andreola  Colby  10194          0                0         0
# 580            Athwal  Sam  10062          0                4         1
# 581       Bachiochi  Linda  10114          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0              1       5            4                       0   62506  ...
# 1              5       3            3                       0  104437  ...
# 2              5       5            3                       0   64955  ...
# 3              1       5            3                       0   64991  ...
# 4              5       5            3                       0   50825  ...
# ..           ...     ...          ...                     ...     ...  ...
# 577            5       5            3                       0   50825  ...
# 578            1       5            4                       0   57568  ...
# 579            1       4            3                       0   95660  ...
# 580            1       5            3                       0   59365  ...
# 581            3       5            3                       1   47837  ...
#
#       Salary_Label  salary_label_num PerformanceScore_id HireDay_Name_id  \
# 0       Low Salary                 0                   0               0
# 1    Medium Salary                 1                   1               1
# 2       Low Salary                 0                   1               0
# 3       Low Salary                 0                   1               1
# 4       Low Salary                 0                   1               1
# ..             ...               ...                 ...             ...
# 577     Low Salary                 0                   1               1
# 578     Low Salary                 0                   0               1
# 579  Medium Salary                 1                   1               1
# 580     Low Salary                 0                   1               1
# 581     Low Salary                 0                   1               1
#
#      E_FirstName E_MiddleName  E_LastName M_first_name M_middle_name  \
# 0         Wilson            K    Adinolfi      Michael           NaN
# 1    Karthikeyan         None    Ait Sidi        Simon           NaN
# 2          Sarah         None  Akinkuolie        Kissy           NaN
# 3          Trina         None      Alagbe      Elijiah           NaN
# 4          Carol         None    Anderson      Webster           NaN
# ..           ...          ...         ...          ...           ...
# 577        Carol         None    Anderson      Webster           NaN
# 578        Linda         None    Anderson          Amy           NaN
# 579        Colby         None    Andreola         Alex           NaN
# 580          Sam         None      Athwal       Ketsia           NaN
# 581        Linda         None   Bachiochi      Brannon           NaN
#
#     M_last_name
# 0        Albert
# 1          Roup
# 2      Sullivan
# 3          Gray
# 4        Butler
# ..          ...
# 577      Butler
# 578        Dunn
# 579  Sweetwater
# 580      Liebig
# 581      Miller
#
# [582 rows x 51 columns]

# %%
df.to_csv('hr_cleaned_data.csv', index=False)
